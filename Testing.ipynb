# %%
import pandas as pd

df_sep = pd.read_csv("Datasets/AirbnbData/Sep.csv")
df_aug = pd.read_csv("Datasets/AirbnbData/Aug.csv")
df_jul = pd.read_csv("Datasets/AirbnbData/July.csv")
print(df_sep.shape)
print(df_aug.shape)
print(df_jul.shape)
# Out:
# (37541, 75)
# (37694, 75)
# (37765, 75)

# %%
df_aug[df_aug["id"].isin(df_sep["id"]) == False]
# Out:
#                         id                                       listing_url  \
# 42                   71248                https://www.airbnb.com/rooms/71248
# 65                   82638                https://www.airbnb.com/rooms/82638
# 224                 270315               https://www.airbnb.com/rooms/270315
# 403                 484312               https://www.airbnb.com/rooms/484312
# 452                 505581               https://www.airbnb.com/rooms/505581
# ...                    ...                                               ...
# 37661  1208183506604880870  https://www.airbnb.com/rooms/1208183506604880870
# 37671  1212547764575762256  https://www.airbnb.com/rooms/1212547764575762256
# 37678  1208801122606304138  https://www.airbnb.com/rooms/1208801122606304138
# 37687  1213029620484893369  https://www.airbnb.com/rooms/1213029620484893369
# 37690  1213120376943076928  https://www.airbnb.com/rooms/1213120376943076928
#
# ...
